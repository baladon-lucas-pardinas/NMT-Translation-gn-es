# %% [markdown]
# # **First attempt of running multiple models in parallel**

# %%
import os

import plots
import constants

import pandas as pd

# %%
MP_FOLDER = constants.MULTIPROCESSING_DATA_FOLDER
FIRST_ATTEMPT_CSV = os.path.join(MP_FOLDER, 'first_attempt.csv')
# METRIC_EVALUATION_FOLDER = constants.METRIC_EVALUATION_FOLDER
# FIRST_ATTEMPT_CSV = os.path.join(METRIC_EVALUATION_FOLDER, 'last_results.csv')

# %%
df = pd.read_csv(FIRST_ATTEMPT_CSV)

# %%
df = df[df['date'] > '2023-07-20']

# %%
plots.plot_metric_by_time_foreach_model(df, 'sacrebleu_corpus_bleu')

# %% [markdown]
# The 2 first parallel models run for 1 day without any issue.
#
# ```
# 2905993    normal   MARIAN alexis.b  R   23:41:59      1 node23
# 2905191    normal   MARIAN alexis.b  R 2-07:23:44      1 node18
# ```

# %% [markdown]
# **ES -> GN**

# %%
plots.plot_metric_by_epoch_foreach_model(df[df['model_name'].str.contains('es_gn', regex=False)], 'sacrebleu_corpus_bleu')

# %%
plots.plot_metric_by_epoch_foreach_model(df[df['model_name'].str.contains('to13', regex=False)], 'sacrebleu_corpus_bleu')

# %% [markdown]
# **GN -> ES**

# %%
plots.plot_metric_by_epoch_foreach_model(df[df['model_name'].str.contains('gn_es', regex=False)], 'sacrebleu_corpus_bleu')

# %% [markdown]
# When did each process finish:
# - es-gn: Cluster Timeout after max_length 300
# - gn-es:
#     - 0-6 haven't finished.
#     - 6-13 finished after this (log_es_gn_test_grid_lvl2_july_grid_from6_to13.log):
#
#                 Error: --type amun does not support multiple encoder layers, use --type s2s
#                 Error: --type amun does not support other rnn cells than gru, use --type s2s
