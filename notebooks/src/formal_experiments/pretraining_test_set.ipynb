# %% [markdown]
# # **Data augmentation in Test Set**

# %%
import os
import sys
import subprocess
import warnings; warnings.filterwarnings('ignore')

import pandas as pd

utils_path = os.path.join(os.getcwd(), '..', '..', '..')
if utils_path not in sys.path:
    sys.path.insert(0, utils_path)

from notebooks.src.utils import plots, constants

# %%
TEST_OUTPUTS_DIR = os.path.join(constants.INSPECTED_DATA_FOLDER, 'test_set')
GOOGLE_TRANSLATIONS_DIR = os.path.join(TEST_OUTPUTS_DIR, 'google')

# %%
architectures = ['transformer', 's2s']
directions = ['gn_es', 'es_gn']
pretraining_options = ['pretraining', 'without_pretraining']
hyperparameter_tuning_options = ['adjusted', 'default']
corpus_names = ['grammar', 'ancora', 'bible', 'merged']

# %%
NOT_PRETRAINED_CORPUS = 'not_pretrained'

model_output = {
    architecture: {
        direction: {
            pretraining_option: {
                hyperparameter_tuning_option: {
                    corpus_name: None for corpus_name in corpus_names + [NOT_PRETRAINED_CORPUS]
                } for hyperparameter_tuning_option in hyperparameter_tuning_options
            } for pretraining_option in pretraining_options
        } for direction in directions
    } for architecture in architectures
}

def get_substring(name: str, substrings: list[str]):
    for substring in substrings:
        if substring in name:
            return substring
    return None

for pretraining_options_dirname in os.listdir(TEST_OUTPUTS_DIR):
    pretraining_options_dir = os.path.join(TEST_OUTPUTS_DIR, pretraining_options_dirname)
    for hyperparameter_tuning_options_dirname in os.listdir(pretraining_options_dir):
        if hyperparameter_tuning_options_dirname not in hyperparameter_tuning_options:
            continue

        hyperparameter_options_dir = os.path.join(pretraining_options_dir, hyperparameter_tuning_options_dirname)
        for output_filename in os.listdir(hyperparameter_options_dir):
            file_architecture = get_substring(output_filename, architectures)
            file_direction = get_substring(output_filename, directions)
            corpus_name = get_substring(output_filename, corpus_names) if pretraining_options_dirname != 'without_pretraining' else NOT_PRETRAINED_CORPUS
            print(file_architecture, file_direction, corpus_name, pretraining_options_dirname, output_filename)
            output_filepath = os.path.join(hyperparameter_options_dir, output_filename)
            print(output_filepath, end='\n\n')
            model_output[file_architecture][file_direction][pretraining_options_dirname][hyperparameter_tuning_options_dirname][corpus_name] = output_filepath
# Out:
# s2s es_gn ancora pretraining decoded_adjusted_ancora_es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_es_gn_s2s.txt
#
# transformer es_gn ancora pretraining decoded_adjusted_ancora_es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_es_gn_transformer.txt
#
# s2s gn_es ancora pretraining decoded_adjusted_ancora_gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_gn_es_s2s.txt
#
# transformer gn_es ancora pretraining decoded_adjusted_ancora_gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_gn_es_transformer.txt
#
# s2s es_gn bible pretraining decoded_adjusted_finetuned_bible_es_gn_s2s_from4.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_es_gn_s2s_from4.txt
#
# transformer es_gn bible pretraining decoded_adjusted_finetuned_bible_es_gn_transformer_from4.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_es_gn_transformer_from4.txt
#
# s2s gn_es bible pretraining decoded_adjusted_finetuned_bible_gn_es_s2s_from3.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_gn_es_s2s_from3.txt
#
# transformer gn_es bible pretraining decoded_adjusted_finetuned_bible_gn_es_transformer_from4.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_gn_es_transformer_from4.txt
#
# s2s es_gn grammar pretraining decoded_adjusted_finetuned_grammar_es_gn_s2s_from2.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_es_gn_s2s_from2.txt
#
# transformer es_gn grammar pretraining decoded_adjusted_finetuned_grammar_es_gn_transformer_from4.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_es_gn_transformer_from4.txt
#
# s2s gn_es grammar pretraining decoded_adjusted_finetuned_grammar_gn_es_s2s_from1.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_gn_es_s2s_from1.txt
#
# transformer gn_es grammar pretraining decoded_adjusted_finetuned_grammar_gn_es_transformer_from3.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_gn_es_transformer_from3.txt
#
# s2s es_gn merged pretraining decoded_adjusted_pretraining_merged_es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_es_gn_s2s.txt
#
# transformer es_gn merged pretraining decoded_adjusted_pretraining_merged_es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_es_gn_transformer.txt
#
# s2s gn_es merged pretraining decoded_adjusted_pretraining_merged_gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_gn_es_s2s.txt
#
# transformer gn_es merged pretraining decoded_adjusted_pretraining_merged_gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_gn_es_transformer.txt
#
# s2s es_gn ancora pretraining decoded_default_ancora__es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__es_gn_s2s.txt
#
# transformer es_gn ancora pretraining decoded_default_ancora__es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__es_gn_transformer.txt
#
# s2s gn_es ancora pretraining decoded_default_ancora__gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__gn_es_s2s.txt
#
# transformer gn_es ancora pretraining decoded_default_ancora__gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__gn_es_transformer.txt
#
# s2s es_gn bible pretraining decoded_default_bible__es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__es_gn_s2s.txt
#
# transformer es_gn bible pretraining decoded_default_bible__es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__es_gn_transformer.txt
#
# s2s gn_es bible pretraining decoded_default_bible__gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__gn_es_s2s.txt
#
# transformer gn_es bible pretraining decoded_default_bible__gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__gn_es_transformer.txt
#
# s2s es_gn grammar pretraining decoded_default_grammar__es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__es_gn_s2s.txt
#
# transformer es_gn grammar pretraining decoded_default_grammar__es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__es_gn_transformer.txt
#
# s2s gn_es grammar pretraining decoded_default_grammar__gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__gn_es_s2s.txt
#
# transformer gn_es grammar pretraining decoded_default_grammar__gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__gn_es_transformer.txt
#
# s2s es_gn merged pretraining decoded_default_merged__es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__es_gn_s2s.txt
#
# transformer es_gn merged pretraining decoded_default_merged__es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__es_gn_transformer.txt
#
# s2s gn_es merged pretraining decoded_default_merged__gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__gn_es_s2s.txt
#
# transformer gn_es merged pretraining decoded_default_merged__gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__gn_es_transformer.txt
#
# s2s es_gn not_pretrained without_pretraining decoded_adjusted_es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_es_gn_s2s.txt
#
# transformer es_gn not_pretrained without_pretraining decoded_adjusted_es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_es_gn_transformer.txt
#
# s2s gn_es not_pretrained without_pretraining decoded_adjusted_gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_gn_es_s2s.txt
#
# transformer gn_es not_pretrained without_pretraining decoded_adjusted_gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_gn_es_transformer.txt
#
# s2s es_gn not_pretrained without_pretraining decoded_default__es_gn_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__es_gn_s2s.txt
#
# transformer es_gn not_pretrained without_pretraining decoded_default__es_gn_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__es_gn_transformer.txt
#
# s2s gn_es not_pretrained without_pretraining decoded_default__gn_es_s2s.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__gn_es_s2s.txt
#
# transformer gn_es not_pretrained without_pretraining decoded_default__gn_es_transformer.txt
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__gn_es_transformer.txt

# %%
data_list = []

for architecture, dir_dict in model_output.items():
    for direction, pretrain_dict in dir_dict.items():
        for pretrain_option, hyper_dict in pretrain_dict.items():
            for hyper_option, corpora_dir in hyper_dict.items():
                for corpus_name, filepath in corpora_dir.items():
                    
                    if filepath is None:
                        continue
                    
                    data_list.append({
                        'architecture': architecture,
                        'pretraining_corpus': corpus_name,
                        'source': direction.split('_')[0],
                        'target': direction.split('_')[1],
                        'pretraining_option': pretrain_option,
                        'hyperparameter_tuning_option': hyper_option,
                        'filepath': filepath
                    })

df = pd.DataFrame(data_list)
df
# Out:
#    architecture pretraining_corpus source target   pretraining_option  \
# 0   transformer            grammar     gn     es          pretraining
# 1   transformer             ancora     gn     es          pretraining
# 2   transformer              bible     gn     es          pretraining
# 3   transformer             merged     gn     es          pretraining
# 4   transformer            grammar     gn     es          pretraining
# 5   transformer             ancora     gn     es          pretraining
# 6   transformer              bible     gn     es          pretraining
# 7   transformer             merged     gn     es          pretraining
# 8   transformer     not_pretrained     gn     es  without_pretraining
# 9   transformer     not_pretrained     gn     es  without_pretraining
# 10  transformer            grammar     es     gn          pretraining
# 11  transformer             ancora     es     gn          pretraining
# 12  transformer              bible     es     gn          pretraining
# 13  transformer             merged     es     gn          pretraining
# 14  transformer            grammar     es     gn          pretraining
# 15  transformer             ancora     es     gn          pretraining
# 16  transformer              bible     es     gn          pretraining
# 17  transformer             merged     es     gn          pretraining
# 18  transformer     not_pretrained     es     gn  without_pretraining
# 19  transformer     not_pretrained     es     gn  without_pretraining
# 20          s2s            grammar     gn     es          pretraining
# 21          s2s             ancora     gn     es          pretraining
# 22          s2s              bible     gn     es          pretraining
# 23          s2s             merged     gn     es          pretraining
# 24          s2s            grammar     gn     es          pretraining
# 25          s2s             ancora     gn     es          pretraining
# 26          s2s              bible     gn     es          pretraining
# 27          s2s             merged     gn     es          pretraining
# 28          s2s     not_pretrained     gn     es  without_pretraining
# 29          s2s     not_pretrained     gn     es  without_pretraining
# 30          s2s            grammar     es     gn          pretraining
# 31          s2s             ancora     es     gn          pretraining
# 32          s2s              bible     es     gn          pretraining
# 33          s2s             merged     es     gn          pretraining
# 34          s2s            grammar     es     gn          pretraining
# 35          s2s             ancora     es     gn          pretraining
# 36          s2s              bible     es     gn          pretraining
# 37          s2s             merged     es     gn          pretraining
# 38          s2s     not_pretrained     es     gn  without_pretraining
# 39          s2s     not_pretrained     es     gn  without_pretraining
#
#    hyperparameter_tuning_option  \
# 0                      adjusted
# 1                      adjusted
# 2                      adjusted
# 3                      adjusted
# 4                       default
# 5                       default
# 6                       default
# 7                       default
# 8                      adjusted
# 9                       default
# 10                     adjusted
# 11                     adjusted
# 12                     adjusted
# 13                     adjusted
# 14                      default
# 15                      default
# 16                      default
# 17                      default
# 18                     adjusted
# 19                      default
# 20                     adjusted
# 21                     adjusted
# 22                     adjusted
# 23                     adjusted
# 24                      default
# 25                      default
# 26                      default
# 27                      default
# 28                     adjusted
# 29                      default
# 30                     adjusted
# 31                     adjusted
# 32                     adjusted
# 33                     adjusted
# 34                      default
# 35                      default
# 36                      default
# 37                      default
# 38                     adjusted
# 39                      default
#
#                                              filepath
# 0   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 1   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 2   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 3   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 4   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 5   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 6   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 7   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 8   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 9   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 10  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 11  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 12  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 13  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 14  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 15  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 16  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 17  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 18  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 19  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 20  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 21  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 22  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 23  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 24  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 25  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 26  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 27  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 28  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 29  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 30  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 31  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 32  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 33  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 34  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 35  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 36  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 37  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 38  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...
# 39  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...

# %%
real_test_set_template = os.path.join(constants.PROJECT_DIR, 'artifacts', 'data', 'test', 'test_{trg}.txt.{trg}')
scorer_script = os.path.join(constants.PROJECT_DIR, 'scripts', 'validate', 'score.py')
score_types = ['sacrebleu_corpus_bleu', 'sacrebleu_corpus_chrf']
scores = {metric: [] for metric in score_types}

def get_score(filepath: str, target: str, metric: str):
    current_reference_file = real_test_set_template.format(trg=target)
    res = subprocess.run(['python', scorer_script, 
                          '--reference_file', current_reference_file, 
                          '--translation_file', filepath, 
                          '--score', metric], 
                          capture_output=True)
    output = res.stdout.decode('utf-8')
    return float(output)

# %%
for metric in score_types:
    for i, row in df.iterrows():
        filepath = row['filepath']
        current_reference_file = real_test_set_template.format(trg=row['target'])
        output = get_score(filepath, row['target'], metric)
        print(f'{os.path.basename(filepath)} {metric}: {output}')
        scores[metric].append(float(output))
        
    df[metric] = scores[metric]
# Out:
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_gn_es_transformer_from3.txt sacrebleu_corpus_bleu: 14.7929
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_gn_es_transformer.txt sacrebleu_corpus_bleu: 17.238
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_gn_es_transformer_from4.txt sacrebleu_corpus_bleu: 14.1128
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_gn_es_transformer.txt sacrebleu_corpus_bleu: 5.83534
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__gn_es_transformer.txt sacrebleu_corpus_bleu: 7.3721
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__gn_es_transformer.txt sacrebleu_corpus_bleu: 7.73653
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__gn_es_transformer.txt sacrebleu_corpus_bleu: 5.4476
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__gn_es_transformer.txt sacrebleu_corpus_bleu: 7.79707
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_gn_es_transformer.txt sacrebleu_corpus_bleu: 4.05493
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__gn_es_transformer.txt sacrebleu_corpus_bleu: 6.59456
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_es_gn_transformer_from4.txt sacrebleu_corpus_bleu: 15.0174
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_es_gn_transformer.txt sacrebleu_corpus_bleu: 17.7025
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_es_gn_transformer_from4.txt sacrebleu_corpus_bleu: 12.0772
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_es_gn_transformer.txt sacrebleu_corpus_bleu: 19.8188
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__es_gn_transformer.txt sacrebleu_corpus_bleu: 4.89617
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__es_gn_transformer.txt sacrebleu_corpus_bleu: 5.83421
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__es_gn_transformer.txt sacrebleu_corpus_bleu: 4.68083
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__es_gn_transformer.txt sacrebleu_corpus_bleu: 6.09434
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_es_gn_transformer.txt sacrebleu_corpus_bleu: 15.9487
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__es_gn_transformer.txt sacrebleu_corpus_bleu: 4.56275
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_gn_es_s2s_from1.txt sacrebleu_corpus_bleu: 25.6581
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_gn_es_s2s.txt sacrebleu_corpus_bleu: 26.8243
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_gn_es_s2s_from3.txt sacrebleu_corpus_bleu: 25.9919
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_gn_es_s2s.txt sacrebleu_corpus_bleu: 26.2075
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__gn_es_s2s.txt sacrebleu_corpus_bleu: 11.1378
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__gn_es_s2s.txt sacrebleu_corpus_bleu: 15.2425
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__gn_es_s2s.txt sacrebleu_corpus_bleu: 11.3331
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__gn_es_s2s.txt sacrebleu_corpus_bleu: 12.8471
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_gn_es_s2s.txt sacrebleu_corpus_bleu: 25.5384
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__gn_es_s2s.txt sacrebleu_corpus_bleu: 3.66959
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_es_gn_s2s_from2.txt sacrebleu_corpus_bleu: 23.509
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_es_gn_s2s.txt sacrebleu_corpus_bleu: 26.165
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_es_gn_s2s_from4.txt sacrebleu_corpus_bleu: 24.0895
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_es_gn_s2s.txt sacrebleu_corpus_bleu: 26.6783
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__es_gn_s2s.txt sacrebleu_corpus_bleu: 11.8249
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__es_gn_s2s.txt sacrebleu_corpus_bleu: 14.6897
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__es_gn_s2s.txt sacrebleu_corpus_bleu: 3.42187
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__es_gn_s2s.txt sacrebleu_corpus_bleu: 14.4455
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_es_gn_s2s.txt sacrebleu_corpus_bleu: 24.3829
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__es_gn_s2s.txt sacrebleu_corpus_bleu: 2.73025
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_gn_es_transformer_from3.txt sacrebleu_corpus_chrf: 39.3789
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_gn_es_transformer.txt sacrebleu_corpus_chrf: 42.4477
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_gn_es_transformer_from4.txt sacrebleu_corpus_chrf: 37.9571
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_gn_es_transformer.txt sacrebleu_corpus_chrf: 31.7407
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__gn_es_transformer.txt sacrebleu_corpus_chrf: 25.7662
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__gn_es_transformer.txt sacrebleu_corpus_chrf: 26.7559
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__gn_es_transformer.txt sacrebleu_corpus_chrf: 21.2819
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__gn_es_transformer.txt sacrebleu_corpus_chrf: 26.5781
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_gn_es_transformer.txt sacrebleu_corpus_chrf: 18.4481
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__gn_es_transformer.txt sacrebleu_corpus_chrf: 23.9646
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_es_gn_transformer_from4.txt sacrebleu_corpus_chrf: 40.1005
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_es_gn_transformer.txt sacrebleu_corpus_chrf: 43.2751
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_es_gn_transformer_from4.txt sacrebleu_corpus_chrf: 36.8171
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_es_gn_transformer.txt sacrebleu_corpus_chrf: 45.2723
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__es_gn_transformer.txt sacrebleu_corpus_chrf: 20.5283
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__es_gn_transformer.txt sacrebleu_corpus_chrf: 23.1446
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__es_gn_transformer.txt sacrebleu_corpus_chrf: 20.8909
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__es_gn_transformer.txt sacrebleu_corpus_chrf: 23.6212
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_es_gn_transformer.txt sacrebleu_corpus_chrf: 40.6309
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__es_gn_transformer.txt sacrebleu_corpus_chrf: 20.377
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_gn_es_s2s_from1.txt sacrebleu_corpus_chrf: 47.4604
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_gn_es_s2s.txt sacrebleu_corpus_chrf: 49.1144
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_gn_es_s2s_from3.txt sacrebleu_corpus_chrf: 47.885
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_gn_es_s2s.txt sacrebleu_corpus_chrf: 49.0953
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__gn_es_s2s.txt sacrebleu_corpus_chrf: 30.55
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__gn_es_s2s.txt sacrebleu_corpus_chrf: 37.086
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__gn_es_s2s.txt sacrebleu_corpus_chrf: 31.3869
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__gn_es_s2s.txt sacrebleu_corpus_chrf: 33.0451
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_gn_es_s2s.txt sacrebleu_corpus_chrf: 47.2416
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__gn_es_s2s.txt sacrebleu_corpus_chrf: 20.7553
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_grammar_es_gn_s2s_from2.txt sacrebleu_corpus_chrf: 46.7344
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_ancora_es_gn_s2s.txt sacrebleu_corpus_chrf: 49.662
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_finetuned_bible_es_gn_s2s_from4.txt sacrebleu_corpus_chrf: 47.3734
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\adjusted\decoded_adjusted_pretraining_merged_es_gn_s2s.txt sacrebleu_corpus_chrf: 50.3821
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_grammar__es_gn_s2s.txt sacrebleu_corpus_chrf: 33.0456
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_ancora__es_gn_s2s.txt sacrebleu_corpus_chrf: 35.4311
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_bible__es_gn_s2s.txt sacrebleu_corpus_chrf: 19.39
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\pretraining\default\decoded_default_merged__es_gn_s2s.txt sacrebleu_corpus_chrf: 35.786
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\adjusted\decoded_adjusted_es_gn_s2s.txt sacrebleu_corpus_chrf: 47.9408
# f:\my_year2023\PLN\code\MARIAN\notebooks\src\utils\..\..\..\notebooks\data\inspected\test_set\without_pretraining\default\decoded_default__es_gn_s2s.txt sacrebleu_corpus_chrf: 18.5673

# %%
google_gn_es_bleu = get_score(os.path.join(GOOGLE_TRANSLATIONS_DIR, 'test_translation_gn_es.txt'), 'es', 'sacrebleu_corpus_bleu')
google_gn_es_chrf = get_score(os.path.join(GOOGLE_TRANSLATIONS_DIR, 'test_translation_gn_es.txt'), 'es', 'sacrebleu_corpus_chrf')
google_es_gn_bleu = get_score(os.path.join(GOOGLE_TRANSLATIONS_DIR, 'test_translation_es_gn.txt'), 'gn', 'sacrebleu_corpus_bleu')
google_es_gn_chrf = get_score(os.path.join(GOOGLE_TRANSLATIONS_DIR, 'test_translation_es_gn.txt'), 'gn', 'sacrebleu_corpus_chrf')

# %%
google_df = pd.DataFrame([{'architecture': 'google',
                            'source': 'gn',
                            'target': 'es',
                            'pretraining_option': 'without_pretraining',
                            'hyperparameter_tuning_option': 'default',
                            'sacrebleu_corpus_bleu': google_gn_es_bleu,
                            'sacrebleu_corpus_chrf': google_gn_es_chrf}, 
                          {'architecture': 'google',
                           'source': 'es',
                           'target': 'gn',
                           'pretraining_option': 'without_pretraining',
                           'hyperparameter_tuning_option': 'default',
                           'sacrebleu_corpus_bleu': google_es_gn_bleu,
                           'sacrebleu_corpus_chrf': google_es_gn_chrf}])

df = pd.concat([df, google_df], axis=0)

# %%
df.sort_values(by=['source', 'sacrebleu_corpus_bleu'], ascending=False)
# Out:
#    architecture pretraining_corpus source target   pretraining_option  \
# 0        google                NaN     gn     es  without_pretraining
# 21          s2s             ancora     gn     es          pretraining
# 23          s2s             merged     gn     es          pretraining
# 22          s2s              bible     gn     es          pretraining
# 20          s2s            grammar     gn     es          pretraining
# 28          s2s     not_pretrained     gn     es  without_pretraining
# 1   transformer             ancora     gn     es          pretraining
# 25          s2s             ancora     gn     es          pretraining
# 0   transformer            grammar     gn     es          pretraining
# 2   transformer              bible     gn     es          pretraining
# 27          s2s             merged     gn     es          pretraining
# 26          s2s              bible     gn     es          pretraining
# 24          s2s            grammar     gn     es          pretraining
# 7   transformer             merged     gn     es          pretraining
# 5   transformer             ancora     gn     es          pretraining
# 4   transformer            grammar     gn     es          pretraining
# 9   transformer     not_pretrained     gn     es  without_pretraining
# 3   transformer             merged     gn     es          pretraining
# 6   transformer              bible     gn     es          pretraining
# 8   transformer     not_pretrained     gn     es  without_pretraining
# 29          s2s     not_pretrained     gn     es  without_pretraining
# 33          s2s             merged     es     gn          pretraining
# 31          s2s             ancora     es     gn          pretraining
# 38          s2s     not_pretrained     es     gn  without_pretraining
# 32          s2s              bible     es     gn          pretraining
# 30          s2s            grammar     es     gn          pretraining
# 13  transformer             merged     es     gn          pretraining
# 1        google                NaN     es     gn  without_pretraining
# 11  transformer             ancora     es     gn          pretraining
# 18  transformer     not_pretrained     es     gn  without_pretraining
# 10  transformer            grammar     es     gn          pretraining
# 35          s2s             ancora     es     gn          pretraining
# 37          s2s             merged     es     gn          pretraining
# 12  transformer              bible     es     gn          pretraining
# 34          s2s            grammar     es     gn          pretraining
# 17  transformer             merged     es     gn          pretraining
# 15  transformer             ancora     es     gn          pretraining
# 14  transformer            grammar     es     gn          pretraining
# 16  transformer              bible     es     gn          pretraining
# 19  transformer     not_pretrained     es     gn  without_pretraining
# 36          s2s              bible     es     gn          pretraining
# 39          s2s     not_pretrained     es     gn  without_pretraining
#
#    hyperparameter_tuning_option  \
# 0                       default
# 21                     adjusted
# 23                     adjusted
# 22                     adjusted
# 20                     adjusted
# 28                     adjusted
# 1                      adjusted
# 25                      default
# 0                      adjusted
# 2                      adjusted
# 27                      default
# 26                      default
# 24                      default
# 7                       default
# 5                       default
# 4                       default
# 9                       default
# 3                      adjusted
# 6                       default
# 8                      adjusted
# 29                      default
# 33                     adjusted
# 31                     adjusted
# 38                     adjusted
# 32                     adjusted
# 30                     adjusted
# 13                     adjusted
# 1                       default
# 11                     adjusted
# 18                     adjusted
# 10                     adjusted
# 35                      default
# 37                      default
# 12                     adjusted
# 34                      default
# 17                      default
# 15                      default
# 14                      default
# 16                      default
# 19                      default
# 36                      default
# 39                      default
#
#                                              filepath  sacrebleu_corpus_bleu  \
# 0                                                 NaN               26.96310
# 21  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               26.82430
# 23  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               26.20750
# 22  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               25.99190
# 20  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               25.65810
# 28  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               25.53840
# 1   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               17.23800
# 25  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               15.24250
# 0   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               14.79290
# 2   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               14.11280
# 27  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               12.84710
# 26  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               11.33310
# 24  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               11.13780
# 7   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                7.79707
# 5   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                7.73653
# 4   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                7.37210
# 9   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                6.59456
# 3   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                5.83534
# 6   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                5.44760
# 8   f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                4.05493
# 29  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                3.66959
# 33  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               26.67830
# 31  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               26.16500
# 38  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               24.38290
# 32  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               24.08950
# 30  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               23.50900
# 13  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               19.81880
# 1                                                 NaN               19.30730
# 11  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               17.70250
# 18  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               15.94870
# 10  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               15.01740
# 35  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               14.68970
# 37  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               14.44550
# 12  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               12.07720
# 34  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...               11.82490
# 17  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                6.09434
# 15  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                5.83421
# 14  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                4.89617
# 16  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                4.68083
# 19  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                4.56275
# 36  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                3.42187
# 39  f:\my_year2023\PLN\code\MARIAN\notebooks\src\u...                2.73025
#
#     sacrebleu_corpus_chrf
# 0                 50.9526
# 21                49.1144
# 23                49.0953
# 22                47.8850
# 20                47.4604
# 28                47.2416
# 1                 42.4477
# 25                37.0860
# 0                 39.3789
# 2                 37.9571
# 27                33.0451
# 26                31.3869
# 24                30.5500
# 7                 26.5781
# 5                 26.7559
# 4                 25.7662
# 9                 23.9646
# 3                 31.7407
# 6                 21.2819
# 8                 18.4481
# 29                20.7553
# 33                50.3821
# 31                49.6620
# 38                47.9408
# 32                47.3734
# 30                46.7344
# 13                45.2723
# 1                 48.9185
# 11                43.2751
# 18                40.6309
# 10                40.1005
# 35                35.4311
# 37                35.7860
# 12                36.8171
# 34                33.0456
# 17                23.6212
# 15                23.1446
# 14                20.5283
# 16                20.8909
# 19                20.3770
# 36                19.3900
# 39                18.5673

# %%
len(df)
# Out:
# 42
